# %% [markdown]
# # Recommendation by Item popularity

# %%
#imports 
import pandas as pd
import numpy as np

#dataframe of songs
df = pd.read_csv(
    'song_data.csv', 
     names =['user_id', 'song_id', 'listen_count', 'title', 'artist']
)


#function that creates a dataframe of items.
#the items are sorted by the feature count in descending order.
#in the list list_of_product_features the user
#can choose what features he wants to display
#if the parameter all_items = True, this function will return the
#dataframe with all the items (so the k will be ignored); otherwise will 
#return the dataframe with only the top k items

def top_k_items(dataframe,
                k,
                user,
                item,
                count,
                list_of_product_features=[],
                all_items=False):
    
    new_df = dataframe.drop(user,1)
    new_df = new_df.reset_index().groupby(item,as_index=False).sum()
    new_df.sort_values(count,ascending=False, inplace=True)
    new_df.drop('index',1,inplace=True)
    new_df.reset_index(inplace=True)
    new_df.drop('index',1,inplace=True)
    if list_of_product_features == []:
        if all_items == False:
            new_df = new_df.loc[range(k)] 
        return new_df
    list_of_product_features = [item] + list_of_product_features
    quasi_df_features = dataframe[list_of_product_features]
    df_features = quasi_df_features.drop_duplicates()
    new_df = pd.merge(new_df,df_features, on=[item])
    if all_items == False:
        new_df = new_df.loc[range(k)] 
    return new_df

# %% [markdown]
# This is our original dataframe

# %%
df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title         artist
# 0         The Cove   Jack Johnson
# 1  Entre Dos Aguas  Paco De Lucia
# 2         Stronger     Kanye West
# 3   Constellations   Jack Johnson
# 4     Learn To Fly   Foo Fighters

# %% [markdown]
# For the first test we want the top 10 items with no information about them, we want only their id

# %%
user, item, count = 'user_id', 'song_id','listen_count' 
test1 = top_k_items(df,10,user,item,count)
test1
# Out:
#               song_id  listen_count
# 0  SOBONKR12A58A7A7E0         40619
# 1  SOAUWYT12A81C206F1         36059
# 2  SOSXLTC12AF72A7F54         30391
# 3  SOEGIYH12A6D4FC0E3         21953
# 4  SOFRQTD12A81C233C0         21646
# 5  SOAXGDH12A8C13F8A1         15889
# 6  SONYKOW12AB01849C9         14149
# 7  SOVDSJC12A58A7A271         14029
# 8  SOUFTBI12AB0183F65         13701
# 9  SOHTKMO12AB01843B0         12506

# %% [markdown]
# The function can return also the dataframe with all the items

# %%
test2 = top_k_items(df,10,user,item,count,all_items=True)
test2.tail()
# Out:
#                  song_id  listen_count
# 9995  SOFFCOP12A8C1422E3            18
# 9996  SOOUXUD12AB0188D97            17
# 9997  SOBZVFU12A6702162C            16
# 9998  SOBDQMB12AB0189045            14
# 9999  SOPWWHY12A58A7B015            12

# %% [markdown]
# Now we add some features to have more information about the items

# %%
features = ['artist','title'] 
test3 = top_k_items(df,30,user,item,count,features)
test3
# Out:
#                song_id  listen_count  \
# 0   SOBONKR12A58A7A7E0         40619
# 1   SOAUWYT12A81C206F1         36059
# 2   SOSXLTC12AF72A7F54         30391
# 3   SOEGIYH12A6D4FC0E3         21953
# 4   SOFRQTD12A81C233C0         21646
# 5   SOAXGDH12A8C13F8A1         15889
# 6   SONYKOW12AB01849C9         14149
# 7   SOVDSJC12A58A7A271         14029
# 8   SOUFTBI12AB0183F65         13701
# 9   SOHTKMO12AB01843B0         12506
# 10  SOOFYTN12A6D4F9B35         12459
# 11  SOPUCYA12A8C13A694         12392
# 12  SOBOUPA12A6D4F81F1         11396
# 13  SODJWHY12A8C142CCE         10133
# 14  SOFLJQZ12A6D4FADA6          9775
# 15  SOLFXKT12AB017E3E0          9551
# 16  SOTCMDJ12A6D4F8528          8839
# 17  SOUDLVN12AAFF43658          8820
# 18  SOTWNDJ12A8C143984          8604
# 19  SOUVTSM12AC468F6A7          8472
# 20  SOUNZHU12A8AE47481          7500
# 21  SOLGLUC12AB018A8FA          7063
# 22  SOWEHOM12A6BD4E09E          6908
# 23  SOUSMXX12AB0185C24          6771
# 24  SOWCKVR12A8C142411          6192
# 25  SORJICW12A8C13640D          6030
# 26  SODGVGW12AC9075A8D          5900
# 27  SOPSOHT12A67AE0235          5820
# 28  SOPTLQL12AB018D56F          5768
# 29  SOPPROJ12AB0184E18          5644
#
#                                                artist  \
# 0                                       Dwight Yoakam
# 1                                               Björk
# 2                                       Kings Of Leon
# 3   Barry Tuckwell/Academy of St Martin-in-the-Fie...
# 4                                            Harmonia
# 5                              Florence + The Machine
# 6                                         OneRepublic
# 7                                           Sam Cooke
# 8                                            Tub Ring
# 9                                       Lonnie Gordon
# 10                                    Alliance Ethnik
# 11                                   Five Iron Frenzy
# 12                                    Alliance Ethnik
# 13                                              Train
# 14                                            Cartola
# 15                                 Charttraxx Karaoke
# 16                                Angels and Airwaves
# 17                                       Bill Withers
# 18                                              Train
# 19                                 Lil Wayne / Eminem
# 20                                         Ron Carter
# 21                                   Die Mooskirchner
# 22                                         The Crests
# 23                          Usher featuring will.i.am
# 24                                      Kings Of Leon
# 25                                           Pavement
# 26                                      Justin Bieber
# 27                                     Randy Crawford
# 28                                       Travie McCoy
# 29                          Kid Cudi / MGMT / Ratatat
#
#                                                 title
# 0                                      You're The One
# 1                                                Undo
# 2                                             Revelry
# 3   Horn Concerto No. 4 in E flat K495: II. Romanc...
# 4                                       Sehr kosmisch
# 5                      Dog Days Are Over (Radio Edit)
# 6                                             Secrets
# 7                                    Ain't Misbehavin
# 8                                             Invalid
# 9   Catch You Baby (Steve Pitron & Max Sanna Radio...
# 10                                         Représente
# 11                                             Canada
# 12                              Sincerité Et Jalousie
# 13                                   Hey_ Soul Sister
# 14                                           Tive Sim
# 15                                          Fireflies
# 16                                           The Gift
# 17                             Make Love To Your Mind
# 18                                           Marry Me
# 19                                     Drop The World
# 20                                I CAN'T GET STARTED
# 21                                  Frisch und g'sund
# 22                                         16 Candles
# 23                                                OMG
# 24                                       Use Somebody
# 25                               Mercy:The Laundromat
# 26                                   Somebody To Love
# 27                                              Almaz
# 28  Billionaire [feat. Bruno Mars]  (Explicit Albu...
# 29                   Pursuit Of Happiness (nightmare)
